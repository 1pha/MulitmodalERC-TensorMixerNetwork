# %%
from erc.interrater import kemdy19_get_rater, kemdy20_get_rater, plot_heatmap, get_irr

# %%
kemdy19 = kemdy19_get_rater()
kemdy20 = kemdy20_get_rater()
# Out:
# Processing ECG / EDA / Label from data/KEMDy19:   0%|          | 0/20 [00:00<?, ?it/s]
# Processing data/KEMDy20_v1_1:   0%|          | 0/40 [00:00<?, ?it/s]

# %%
mask = kemdy19[1]["segment_id"].str.contains("_impro")

# %% [markdown]
# ## Heatmaps for Inter-rater Valence & Arousal Rating

# %%
plot_heatmap(df=kemdy19[1], group_idx=1, mask="_script")

# %%
plot_heatmap(df=kemdy19[1], group_idx=1, mask="_impro")

# %%
plot_heatmap(df=kemdy19[2], group_idx=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_heatmap(df=kemdy19[2], group_idx=2)
#
# File ~/codespace/etri-erc/erc/interrater.py:162, in plot_heatmap(df, group_idx, mask)
#     160 fig, ax = plt.subplots(figsize=(14, 6), ncols=2)
#     161 group_name = "" if group_idx is None else f"Rater Group {group_idx}: "
# --> 162 _plot_heatmap(df=df, col="arousal", ax=ax[0], group_name=group_name, mask=mask)
#     163 _plot_heatmap(df=df, col="valence", ax=ax[1], group_name=group_name, mask=mask)
#
# File ~/codespace/etri-erc/erc/interrater.py:153, in _plot_heatmap(df, col, ax, group_name, mask)
#     151         mask = df["segment_id"].str.contains(mask)
#     152         df = df[col][mask]
# --> 153 corr = df.astype(float).corr()
#     154 title = f"{group_name if group_name is not None else ''} {col}"
#     155 ax.set_title(title.capitalize())
#
# AttributeError: 'dict' object has no attribute 'astype'

# %%
plot_heatmap(df=kemdy20[1], group_idx=3)

# %% [markdown]
# ## CAC: Fleiss Kappa, Krippendorff

# %%
print("KEMDY19 Rater Group 1")
get_irr(df=kemdy19[1])
get_irr(df=kemdy19[1], label="arousal")
get_irr(df=kemdy19[1], label="valence")


print("\nKEMDY19 Rater Group 2")
get_irr(df=kemdy19[2])
get_irr(df=kemdy19[2], label="arousal")
get_irr(df=kemdy19[2], label="valence")

print("\nKEMDY20 Rater Group 3")
get_irr(df=kemdy20[1])
get_irr(df=kemdy20[1], label="arousal")
get_irr(df=kemdy20[1], label="valence");
# Out:
# KEMDY19 Rater Group 1
# emotion
# Fleiss Kappa: 0.49143	Krippendorff: 0.49144
# arousal
# Fleiss Kappa: 0.27067	Krippendorff: 0.27068
# valence
# Fleiss Kappa: 0.33533	Krippendorff: 0.33534
#
# KEMDY19 Rater Group 2
# emotion
# Fleiss Kappa: 0.50498	Krippendorff: 0.50499
# arousal
# Fleiss Kappa: 0.29835	Krippendorff: 0.29836
# valence
# Fleiss Kappa: 0.36824	Krippendorff: 0.36825
#
# KEMDY20 Rater Group 3
# emotion
# Fleiss Kappa: 0.24115	Krippendorff: 0.24115
# arousal
# Fleiss Kappa: 0.07716	Krippendorff: 0.07717
# valence
# Fleiss Kappa: 0.2233	Krippendorff: 0.22331

# %%
mask = "_script"
print("KEMDY19 Rater Group 1")
get_irr(df=kemdy19[1], label="emotion", mask=mask)
get_irr(df=kemdy19[1], label="arousal", mask=mask)
get_irr(df=kemdy19[1], label="valence", mask=mask)


print("\nKEMDY19 Rater Group 2")
get_irr(df=kemdy19[2], label="emotion", mask=mask)
get_irr(df=kemdy19[2], label="arousal", mask=mask)
get_irr(df=kemdy19[2], label="valence", mask=mask);
# Out:
# KEMDY19 Rater Group 1
# emotion
# Fleiss Kappa: 0.50523	Krippendorff: 0.50525
# arousal
# Fleiss Kappa: 0.27879	Krippendorff: 0.27882
# valence
# Fleiss Kappa: 0.33131	Krippendorff: 0.33133
#
# KEMDY19 Rater Group 2
# emotion
# Fleiss Kappa: 0.50021	Krippendorff: 0.50023
# arousal
# Fleiss Kappa: 0.28768	Krippendorff: 0.28771
# valence
# Fleiss Kappa: 0.36689	Krippendorff: 0.36691

# %%
mask = "_impro"
print("KEMDY19 Rater Group 1")
get_irr(df=kemdy19[1], label="emotion", mask=mask)
get_irr(df=kemdy19[1], label="arousal", mask=mask)
get_irr(df=kemdy19[1], label="valence", mask=mask)


print("\nKEMDY19 Rater Group 2")
get_irr(df=kemdy19[2], label="emotion", mask=mask)
get_irr(df=kemdy19[2], label="arousal", mask=mask)
get_irr(df=kemdy19[2], label="valence", mask=mask);
# Out:
# KEMDY19 Rater Group 1
# emotion
# Fleiss Kappa: 0.45792	Krippendorff: 0.45795
# arousal
# Fleiss Kappa: 0.24168	Krippendorff: 0.24172
# valence
# Fleiss Kappa: 0.33538	Krippendorff: 0.33541
#
# KEMDY19 Rater Group 2
# emotion
# Fleiss Kappa: 0.50739	Krippendorff: 0.50741
# arousal
# Fleiss Kappa: 0.30824	Krippendorff: 0.30827
# valence
# Fleiss Kappa: 0.36796	Krippendorff: 0.36799
