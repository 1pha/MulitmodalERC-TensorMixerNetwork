# %%
import torch 
checkpoint = torch.load("/home/hoesungryu/etri-erc/weights_AI_HUB/aihub_RobertaL_valid_acc0.993.ckpt")
state_dict = checkpoint["state_dict"]

# %%
torch.save({'state_dict': checkpoint["state_dict"]}, "/home/hoesungryu/etri-erc/weights_AI_HUB/RobertaL_pretrained(aihub)_weight.ckpt")
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
tips = sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill")

# %%
import seaborn as sns 
geyser = sns.load_dataset("geyser")
# sns.kdeplot(data=geyser, x="waiting", y="duration", hue="kind")

# %%
geyser['kind'] = geyser['kind'].map({"long":"valence","short":"arousal"})
geyser.columns = ['duration', 'waiting', 'Regression']

# %%
geyser
# Out:
#      duration  waiting Regression
# 0       3.600       79    valence
# 1       1.800       54    arousal
# 2       3.333       74    valence
# 3       2.283       62    arousal
# 4       4.533       85    valence
# ..        ...      ...        ...
# 267     4.117       81    valence
# 268     2.150       46    arousal
# 269     4.417       90    valence
# 270     1.817       46    arousal
# 271     4.467       74    valence
#
# [272 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
sns.kdeplot(
    data=geyser, x="waiting", y="duration", hue="Regression",fill=True
)
sns.set_style("white")
sns.despine()
plt.xlabel(None)
plt.ylabel(None)
plt.legend()
plt.xticks([])
plt.yticks([])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ([], [])

# %%
state_dict
# Out:
# OrderedDict([('model.wav_model.masked_spec_embed',
#               tensor([ 0.5823,  0.4831, -0.9796,  ...,  0.5764, -0.4952, -0.2375],
#                      device='cuda:0')),
#              ('model.wav_model.feature_extractor.conv_layers.0.conv.weight',
#               tensor([[[-0.0304,  0.0598, -0.0828,  ...,  0.1011, -0.0719,  0.0286]],
#
#                       [[-0.0610,  0.2045, -0.3387,  ..., -0.2470,  0.1773, -0.0565]],
#
#                       [[-0.0754,  0.1939, -0.2705,  ...,  0.1463, -0.0727,  0.0211]],
#
#                       ...,
#
#                       [[ 0.0901, -0.0277, -0.0020,  ...,  0.2125, -0.2969, -0.1361]],
#
#                       [[-0.0824,  0.0695,  0.0467,  ...,  0.0190, -0.0289,  0.0354]],
#
#                       [[ 0.0050, -0.0198,  0.0400,  ...,  0.0233,  0.0034, -0.0032]]],
#                      device='cuda:0')),
#              ('model.wav_model.feature_extractor.conv_layers.0.conv.bias',
# ...

# %%
torch.save(
                {
                    'model_state_dict': model_params,
                    'optimizer_state_dict': optimizer.state_dict(),
                    'lr_scheduler_state_dict': lr_scheduler.state_dict(),
                    'epoch': epoch,
                    'total_iter_num': total_iter_num,
                    'epoch_loss': epoch_loss,
                    'config': config_yaml
                }, filename)
